# %%
import pandas as pd

# %%
df = pd.read_csv('../data/april28-may6_full.csv')

# %%
df.tail()
# Out:
#        Unnamed: 0   screen_name      username             tweet_id  \
# 12904       12904       Angeloj  AJ Crawdaddy  1257889164411965440
# 12905       12905    queendior7  Tashia-Semaj  1257889828471013377
# 12906       12906  4PocketzFull           DWA  1257889917335744512
# 12907       12907      adrlopez  Adrian Lopez  1257890170558390273
# 12908       12908        pidybi  𝔓𝔦𝔬𝔱𝔯 𝔇𝔶𝔟𝔦𝔢𝔠  1257891112301330433
#
#                  timestamp                                               text  \
# 12904  2020-05-06 04:25:21  “Live music” will survive!  We will ROCK again...
# 12905  2020-05-06 04:28:00  The perks of having a sister that is a hairsty...
# 12906  2020-05-06 04:28:21  I’m A Rare Breed. They Not Supposed To Underst...
# 12907  2020-05-06 04:29:21  Celebrating  Cinco de Mayo  on Taco  Tuesday w...
# 12908  2020-05-06 04:33:06  #aljazeera #Trump to wind down...https://www.a...
#
#                                                 hashtags  likes  retweets  \
# ...

# %%
ny_index_list = []

for num in range(0,12909):
    if 'NY' in df['location'][num]:
        ny_index_list.append(num)
        
len(ny_index_list)
# Out:
# 1305

# %%
tx_index_list = []

for num in range(0,12909):
    if 'TX' in df['location'][num]:
        tx_index_list.append(num)
        
len(tx_index_list)
# Out:
# 427

# %%
ny_df = df.loc[ny_index_list,:]

# %%
ny_df['city'] = [item.split(',')[0] for item in ny_df['location']]

# %%
ny_df['state'] = [item.split(',')[1] for item in ny_df['location']]

# %%
tx_df = df.loc[tx_index_list,:]

# %%
tx_df['city'] = [item.split(',')[0] for item in tx_df['location']]
tx_df['state'] = [item.split(',')[1] for item in tx_df['location']]

# %%
tx_df.head()
# Out:
#      Unnamed: 0    screen_name                 username             tweet_id  \
# 30           30       all512tv      Austin Live & Local  1255008728711000065
# 82           82        joshWUa                  joshWUa  1255022095626571776
# 138         138       malele76  #indal_yam_botq 👗👠👞🛍👝👜🕶  1255037758588026880
# 170         170  phonemarttech                PhoneMart  1255047959420403713
# 209         209     JakobEbert         Jakob Ebert, BVK  1255057661013356544
#
#                timestamp                                               text  \
# 30   2020-04-28 05:39:32  http://subscribe.all512.com  From Texas Standa...
# 82   2020-04-28 06:32:39  Here everyone he found the cure for your #covi...
# 138  2020-04-28 07:34:53  Let's be warm with this colourful cotton Gucci...
# 170  2020-04-28 08:15:25  INSTAGRAM COVID-19 CASH GIVE AWAY CONTINUES !!...
# 209  2020-04-28 08:53:58  COVID-19\n#investing #mood #memes @ Berlin, Ge...
#
# ...

# %%
df = pd.read_csv('../data/tweets_and_covid.csv')

# %%
df.sort_values('city')
# Out:
#          screen_name          username             tweet_id  \
# 1610    nigeriatunes  Number 1 Agbero.  1257122286596845568
# 1580            WBOP  Victor Zimmerman  1256749752403836934
# 1317          BC_904              ⬛⬛⬛⬛  1255169486669459462
# 1476    TimminsToday  TimminsToday.com  1256239086160867328
# 846     mostrecently   Johannes Jüngst  1256955538178551808
# ...              ...               ...                  ...
# 920       egbonlekan   Ibuoye Olalekan  1257093590649655297
# 957    PastorHThomas  Bishop H. Thomas  1257215541997076481
# 316         inkdbyaj        INKD BY AJ  1255694636728942592
# 610       IPARKMUSIC            OOBANG  1256419983900450817
# 784   TORsAdventures    TORsAdventures  1256720004818534400
#
#           tweet_timestamp                                               text  \
# 1610  2020-05-04 01:38:03  Cross River preparing for life after COVID-19,...
# 1580  2020-05-03 00:57:44  Reminder! Gov. Baker announced that the state’...
# ...
